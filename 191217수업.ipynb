# %% [markdown]
# `models.create`에서 blank=True 는 관리자 페이지에서 널 값을 허용할 것이냐?

# %%
Post.objects.get(username='admin')
# Out:
# ---------------------------------------------------------------------------
# FieldError                                Traceback (most recent call last)
# <ipython-input-1-e66e05193c83> in <module>
# ----> 1 Post.objects.get(username='admin')
#
# ~/.pyenv/versions/3.7.5/envs/wps-djangogirls-env/lib/python3.7/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      80         def create_method(name, method):
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#      84             manager_method.__doc__ = method.__doc__
#
# ~/.pyenv/versions/3.7.5/envs/wps-djangogirls-env/lib/python3.7/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     397         keyword arguments.
#     398         """
# --> 399         clone = self.filter(*args, **kwargs)
# ...
